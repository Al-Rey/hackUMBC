# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %% [markdown]
# # Import Data

# %%
data = pd.read_json("motif_dataset.json", lines=True)

# %%
data.columns
# Out:
# Index(['md5', 'sha1', 'sha256', 'reported_hash', 'reported_family', 'aliases',
#        'label', 'report_source', 'report_date', 'report_url', 'report_ioc_url',
#        'appeared', 'histogram', 'byteentropy', 'strings', 'general', 'header',
#        'section', 'imports', 'exports', 'datadirectories'],
#       dtype='object')

# %%
data.drop(["report_url", "report_ioc_url", "histogram", "label", "report_date", "byteentropy"], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['md5', 'sha1', 'sha256', 'reported_hash', 'reported_family', 'aliases',
#        'report_source', 'appeared', 'strings', 'general', 'header', 'section',
#        'imports', 'exports', 'datadirectories'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %%
data.iloc[:, 5:].head(3)
# Out:
#                            aliases report_source appeared  \
# 0             [shamoon, disttrack]      Symantec  2018-12
# 1  [downdelph, delphacy, delphocy]          ESET  2016-10
# 2      [discordiaminer, discordia]     Kaspersky  2017-05
#
#                                              strings  \
# 0  {'numstrings': 8626, 'avlength': 6.32216554602...
# 1  {'numstrings': 472, 'avlength': 9.921610169491...
# 2  {'numstrings': 1058, 'avlength': 14.2249527410...
#
#                                              general  \
# 0  {'size': 1921024, 'vsize': 1921024, 'has_debug...
# 1  {'size': 111616, 'vsize': 155648, 'has_debug':...
# 2  {'size': 245248, 'vsize': 266240, 'has_debug':...
#
#                                               header  \
# 0  {'coff': {'timestamp': 1322495459, 'machine': ...
# 1  {'coff': {'timestamp': 1399967918, 'machine': ...
# 2  {'coff': {'timestamp': 1496077247, 'machine': ...
#
#                                              section  \
# 0  {'entry': '.text', 'sections': [{'name': '.tex...
# 1  {'entry': '.text', 'sections': [{'name': '.tex...
# 2  {'entry': '.text', 'sections': [{'name': '.tex...
#
#                                              imports exports  \
# 0  {'NETAPI32.dll': ['NetScheduleJobAdd', 'NetUse...      []
# 1  {'oleaut32.dll': ['SysFreeString', 'SysReAlloc...      []
# 2  {'KERNEL32.dll': ['Sleep', 'GetLastError', 'Mu...      []
#
#                                      datadirectories
# 0  [{'name': 'EXPORT_TABLE', 'size': 0, 'virtual_...
# 1  [{'name': 'EXPORT_TABLE', 'size': 0, 'virtual_...
# 2  [{'name': 'EXPORT_TABLE', 'size': 0, 'virtual_...

# %%
data.loc[0, "general"]
# Out:
# {'size': 1921024,
#  'vsize': 1921024,
#  'has_debug': 0,
#  'exports': 0,
#  'imports': 163,
#  'has_relocations': 1,
#  'has_resources': 1,
#  'has_signature': 0,
#  'has_tls': 0,
#  'symbols': 0}

# %%
data["file_size_bytes"]=data["general"].agg(lambda x: x["size"])
data["virtual_file_size_bytes"]=data["general"].agg(lambda x: x["vsize"])
data["has_debug"]=data["general"].agg(lambda x: x["has_debug"])
data["num_exports"]=data["general"].agg(lambda x: x["exports"])
data["num_imports"]=data["general"].agg(lambda x: x["imports"])
data["has_resources"]=data["general"].agg(lambda x: x["has_resources"])

# %%
data.loc[0, "strings"]
# Out:
# {'numstrings': 8626,
#  'avlength': 6.322165546023649,
#  'printabledist': [1545,
#   409,
#   383,
#   366,
#   465,
#   331,
#   422,
#   552,
#   415,
#   410,
#   351,
#   376,
#   520,
#   488,
#   446,
#   373,
#   634,
#   537,
#   385,
#   457,
#   1315,
#   456,
#   417,
#   536,
#   481,
#   414,
#   470,
#   482,
#   468,
#   442,
#   488,
#   508,
#   647,
#   530,
#   746,
#   542,
#   557,
#   513,
#   506,
#   791,
#   536,
#   452,
#   557,
#   421,
#   538,
#   481,
#   548,
#   375,
#   592,
#   394,
#   476,
#   624,
#   469,
#   374,
#   473,
#   502,
#   484,
#   438,
#   433,
#   439,
#   360,
#   381,
#   420,
#   430,
#   455,
#   802,
#   469,
#   1074,
#   543,
#   1155,
#   488,
#   522,
#   1362,
#   1219,
#   472,
#   569,
#   818,
#   533,
#   696,
#   769,
#   561,
#   396,
#   855,
#   720,
#   975,
#   546,
#   427,
#   750,
#   1226,
#   494,
#   389,
#   1194,
#   429,
#   485,
#   361,
#   410],
#  'printables': 54535,
#  'entropy': 6.475968360900879,
#  'paths': 0,
#  'urls': 0,
#  'registry': 0,
#  'MZ': 18}

# %%
data["num_strings"]=data["strings"].agg(lambda x: x["numstrings"])
data["avg_string_len"]=data["strings"].agg(lambda x: x["avlength"])
data["num_printable_strings"]=data["strings"].agg(lambda x: x["printables"])
data["num_path_strings"]=data["strings"].agg(lambda x: x["paths"])
data["num_url_strings"]=data["strings"].agg(lambda x: x["urls"])
data["num_registry_strings"]=data["strings"].agg(lambda x: x["registry"])

# %%
# data.head(4)

# %%
data.loc[789, "section"]
# Out:
# {'entry': '.text',
#  'sections': [{'name': '.text',
#    'size': 40960,
#    'entropy': 5.680471600569829,
#    'vsize': 38364,
#    'props': ['CNT_CODE', 'MEM_EXECUTE', 'MEM_READ']},
#   {'name': '.data',
#    'size': 4096,
#    'entropy': -0.0,
#    'vsize': 6544,
#    'props': ['CNT_INITIALIZED_DATA', 'MEM_READ', 'MEM_WRITE']},
#   {'name': '.rsrc',
#    'size': 237568,
#    'entropy': 5.405046225418915,
#    'vsize': 235498,
#    'props': ['CNT_INITIALIZED_DATA', 'MEM_READ']}]}

# %%
data["entry_point"]=data["section"].agg(lambda x: x["entry"])

# %%
sec = set()
x = data[["section"]].copy()
for row in x["section"]:
    for i in row["sections"]:
        sec.add(i["name"])
        
        
sec
# Out:
# {'',
#  '\x03}AI?s\x0f',
#  '\x047K"PY\x16\t',
#  '\x15J\x03\x14\x17\x0e\x17W',
#  '\x19\x19\x0cLDP\x04@',
#  ' ',
#  '   ',
#  '        ',
#  '"a%\x01\x0e1\x10w',
#  '$LI[EU^-',
#  '$hVzesTS',
#  "'5?#(IbB",
#  "'HU\x1f,\x06a\x1b",
#  '(w:$>1]l',
#  '*^I)JH`\\',
#  '+XT|sS4',
#  '-4',
#  '.',
#  '.00cfg',
#  '.1LA',
#  '.8010',
#  '.8011',
#  '.BSS',
#  '.BSS3',
#  '.BSS4',
#  '.CRT',
#  '.HOKKES',
#  '.HOOKDAT',
#  '.MPRESS1',
#  '.MPRESS2',
#  '.NewIT',
#  '.SCY',
#  '.SE',
#  '.Silvana',
#  '.UPX',
#  '.UPX0',
#  '.UPX1',
#  '.UPX2',
#  '.X1D',
#  '.Xyl2k!',
#  '.a050',
#  '.a051',
#  '.adata',
#  '.api',
#  '.arch',
#  '.aspack',
#  '.barusec',
#  '.bin',
#  '.bss',
#  '.bss0',
#  '.bxoer',
#  '.cctype',
#  '.cdata',
#  '.cfg',
#  '.code',
#  '.cotx',
#  '.crt',
#  '.crt0',
#  '.crt1',
#  '.cwtnsn',
#  '.data',
#  '.data1',
#  '.data2',
#  '.data4',
#  '.dec',
#  '.didat',
#  '.didata',
#  '.dll0',
#  '.dll1',
#  '.dtext',
#  '.edata',
#  '.eh_fram',
#  '.enigma1',
#  '.enigma2',
#  '.erloc',
#  '.eyolc',
#  '.f',
#  '.fdata',
#  '.fg15',
#  '.flat',
#  '.gcode',
#  '.gdata',
#  '.gdb0',
#  '.gdb1',
#  '.gerc',
#  '.gfids',
#  '.ggeE',
#  '.gig',
#  '.grrr',
#  '.guids',
#  '.hand',
#  '.hereve',
#  '.idata',
#  '.idata  ',
#  '.idata2',
#  '.img',
#  '.imports',
#  '.itext',
#  '.jdata',
#  '.jwfjhjx',
#  '.kdata',
#  '.kecujex',
#  '.kezixof',
#  '.ldata',
#  '.lesupoj',
#  '.lib0',
#  '.lib1',
#  '.mackt',
#  '.mdata',
#  '.mfnxy',
#  '.monor',
#  '.msvcjmc',
#  '.mysec',
#  '.mysec2',
#  '.nate0',
#  '.nate1',
#  '.ndata',
#  '.nec',
#  '.nice020',
#  '.nice021',
#  '.nojiri',
#  '.nsp0',
#  '.nsp1',
#  '.nsp2',
#  '.nvFatBi',
#  '.nv_fatb',
#  '.opc',
#  '.pack0',
#  '.pack1',
#  '.pako',
#  '.pck0',
#  '.pck1',
#  '.pdata',
#  '.pit',
#  '.po1',
#  '.po2',
#  '.po3',
#  '.po4',
#  '.popdata',
#  '.pvm0',
#  '.pvm1',
#  '.qdata',
#  '.rcrs',
#  '.rd',
#  '.rdata',
#  '.rdata\x01',
#  '.rdata  ',
#  '.rdata15',
#  '.rdata2',
#  '.rdata3',
#  '.rdata4',
#  '.rdata5',
#  '.reloc',
#  '.reloc1',
#  '.relos',
#  '.riz',
#  '.rlc',
#  '.rodata',
#  '.rofeviv',
#  '.roj',
#  '.rrr',
#  '.rsrc',
#  '.rsrc   ',
#  '.rtxt0',
#  '.rtxt1',
#  '.ruf',
#  '.sa',
#  '.sdata',
#  '.sql',
#  '.st',
#  '.stub',
#  '.sxdata',
#  '.symtab',
#  '.taggant',
#  '.tavat',
#  '.tdata',
#  '.terro',
#  '.texT',
#  '.text',
#  '.text0',
#  '.text1',
#  '.text5',
#  '.text8',
#  '.textXJ;',
#  '.texta',
#  '.textbs',
#  '.textbss',
#  '.textc',
#  '.textff3',
#  '.tls',
#  '.tosubiz',
#  '.upx0',
#  '.upx1',
#  '.vdata',
#  '.version',
#  '.vl',
#  '.vmp0',
#  '.vmp1',
#  '.vmp2',
#  '.vqCp0w',
#  '.vuhido',
#  '.wat',
#  '.woj',
#  '.x0',
#  '.x1',
#  '.x2',
#  '.xav',
#  '.xdata',
#  '.xml',
#  '.xxxx',
#  '.xyli0',
#  '.xyli1',
#  '.ydata',
#  '.yss',
#  '.zan',
#  '.zdata',
#  '.zecubex',
#  '.zero',
#  '.zojuwo',
#  '/102',
#  '/113',
#  '/124',
#  '/14',
#  '/18',
#  '/19',
#  '/29',
#  '/30',
#  '/31',
#  '/35',
#  '/4',
#  '/41',
#  '/43',
#  '/45',
#  '/51',
#  '/55',
#  '/57',
#  '/63',
#  '/67',
#  '/70',
#  '/71',
#  '/77',
#  '/80',
#  '/81',
#  '/87',
#  '/89',
#  '/92',
#  "2\x1a/'/;\n$",
#  '2r/K*b82',
#  '2uNQ8/<`',
#  '6333yMVu',
#  '6LS5rMVD',
#  '6rTahvgu',
#  "8'PRSxv<",
#  '86APWYZZ',
#  '8QAt3JKg',
#  '8\\?$',
#  '8d1Q=',
#  ';\\x98]N\\xb5Ex\\xd7',
#  '=\x1a\\xee,0',
#  '=\x1a\\xee,1',
#  '=\x1a\\xee,2',
#  '>\x13NS\x10\x11Vv',
#  '>Yd8OWZ`',
#  'A.$S3b%=',
#  'B',
#  'BM\\xfe\\xfa\\x9b\x1c\\x9d\\xc5',
#  'BSS',
#  'B~-euh',
#  'CODE',
#  "D3'&DZ3'",
#  'DATA',
#  'DQ\x0e@W"\x08\x06',
#  'E%HIHm',
#  'EQa(![Zu',
#  'ExeS',
#  'FX&zXwJ\x02',
#  'H.u.A3',
#  'HS:86"aU',
#  'IAT_SEC_',
#  'INIT',
#  'Io,H{Jo',
#  'JTWvhDOU',
#  'JmGQVuhD',
#  'L!NK',
#  'LxHIHQx',
#  'MVXY1xNo',
#  'NTtLSYwN',
#  'O5r1uUqs',
#  'O8bbwJAc',
#  'OUseEkc8',
#  'Ozm\x14X\x15\x16\\',
#  'PAGE',
#  'PAGEDATA',
#  'PAGEMSG',
#  'PAGENDCO',
#  'PAGENDSE',
#  'PAGENDSM',
#  'PAGENDSP',
#  'PAGENDST',
#  'PAGENPNP',
#  'PAK0',
#  'PROCESS_',
#  'R\x16g\x1bY`Z\x16',
#  'U>om_LUz',
#  'UPX0',
#  'UPX1',
#  'UPX2',
#  'USwz\x05nUo',
#  'Ucode',
#  'VB?"N?ct',
#  'W*vaF',
#  'X0vMqd6A',
#  'Xm ',
#  'Z`6S\x1f6\tI',
#  'ZlOK9YE0',
#  '[.i?!L?1',
#  '\\x82\\x9dw\\xd1!\\xb9\x1d\\xdf',
#  '\\xa6\\xe05\\xf0BM\\xfe+',
#  '\\xb3\\xa8f\x033\x04\x19\\x88',
#  '\\xc0\\xe2\\xefX\\x87\x1e\\x96\\',
#  '\\xd2$\\xd1!\x1d\x1c\\xccr',
#  '\\xdb\\xf6\\xc8\\xd0Q\x06\x1aw',
#  '\\xe3\\x9c\x06G\\xd3\\x84\\xee\\xde',
#  '\\xfe=\\x82\\xc6\\xc4BT,',
#  '_RDATA',
#  '__\\xc7\\x9fp\\xd1L\\xd2',
#  '`&\nf}+6\t',
#  '`KB=1u]r',
#  '`g\rA0220',
#  'a2',
#  'a21',
#  'a3',
#  'a32',
#  'a322',
#  'a356f',
#  'abgfwqxc',
#  'ahuxfhvm',
#  'ajufzdzm',
#  'akfhnogc',
#  'aracruz',
#  'atexit',
#  'atoi',
#  'bbbb',
#  'bbiriihq',
#  'bddtmwqf',
#  'bkelsnre',
#  'bknaotkp',
#  'bncavhpe',
#  'c\\xc1\\xb7\t\\xee\\xd8\\xb8@',
#  'cd%2NVHn',
#  'cgzbjkgh',
#  'cjcevymh',
#  'clkzhmvf',
#  'code',
#  'cpbtgtlc',
#  'csgwmvly',
#  'data',
#  'dfqkoyck',
#  'dfyvwsqe',
#  'dphyaufc',
#  'dqmizkaq',
#  'duwzojdk',
#  'dworqjxn',
#  'dwukfuez',
#  'dzgjiwxo',
#  'eaV"2x9/',
#  'ebkzhxkx',
#  'eepqalit',
#  'ewmlyboq',
#  'exit',
#  'f94xga5z',
#  'f:\x08=4j?b',
#  'fdoaclbr',
#  'ffA4KFw2',
#  'ffdtqvfu',
#  'fgwvbapa',
#  'fkN(\r?]6',
#  'fwlmrvta',
#  'fxeqrxnm',
#  'fzqtshtl',
#  'gG,pO%8=',
#  'garh',
#  'gjrlfbo',
#  'gpfudcjl',
#  'gqnfphil',
#  'gqnsedze',
#  'gupMTg9a',
#  'gwbsfjhz',
#  'hnurncwg',
#  'hqhlhnjp',
#  'htusmqub',
#  'hupikqzb',
#  'hwgnkmmj',
#  'hzlvukxv',
#  'iGyQBb0B',
#  'iimJn6P',
#  'ijybpcqb',
#  'iltjiknc',
#  'iphsgnrl',
#  'iqffpbdv',
#  'j\x0bkM4jv\x0c',
#  'j8',
#  'jbazrsfp',
#  'jjpwwfxw',
#  'kciriszh',
#  'kfxyonok',
#  'koggvbzi',
#  'kzjfnkee',
#  'ldawqpjn',
#  'llizqgno',
#  'lpjdlseu',
#  'lvyacjmk',
#  'mLsHLmSV',
#  'mbvzkrzs',
#  'mjttvgpn',
#  'mteprmrb',
#  'mwmijvhl',
#  'na*\x02x\x1bA\x10',
#  'niotlapu',
#  'nmpsuipr',
#  'nsmwnsbj',
#  'ohmhxtqs',
#  'omcbvjc',
#  'omrcmqfn',
#  'oqamosbi',
#  'piarailp',
#  'pkaswjjk',
#  'popwbokb',
#  'psmxndys',
#  'pyrbzwin',
#  "qJ.d'z;L",
#  'qqoeajvx',
#  'qrlmmrjj',
#  'rfqpqjvd',
#  'rmfyimys',
#  'rsrc',
#  'sdfvsczx',
#  'sdqv3e3',
#  'section',
#  'slgtbweo',
#  'sndfykis',
#  'sty',
#  'tdxaqysc',
#  'tilkteny',
#  'tmlckjda',
#  'todbisgp',
#  'ttjjbpcp',
#  'tuvalu',
#  'uZz',
#  'ubwcodgm',
#  'ud$+y4s\x01',
#  'uklqtnxb',
#  'uknuupss',
#  'ukocrbor',
#  'uojrvipy',
#  'upltmyet',
#  'uvlyfmdf',
#  'uvycnhmx',
#  'v\\n#Mnnw',
#  'vguyl',
#  'vmp0',
#  'vmp1',
#  'vubbqlpp',
#  'wLnd8zOp',
#  'wTn456V,',
#  'wewiiisw',
#  'wgvupijp',
#  'x]ierR^n',
#  'xgn~',
#  'xgreusrx',
#  'xkbhtixa',
#  'xneiiynd',
#  'xrosyklx',
#  'y\\xa3\\xe1\\xc7\\x8f\\xc4\\xb6l',
#  'ycnjalxz',
#  'ydccuxex',
#  'yfyrvozs',
#  'yiazfxnd',
#  'yjimiswp',
#  'yjpxowuy',
#  'yrauzmga',
#  'z2g$&S\x03\x1d',
#  'zltctfkm',
#  'ztlkwwzl',
#  'zyhtzmcz',
#  '~@37dX'}

# %%
def GetSectionData(x, want): # (section, key)
    sections = x["sections"]
    # print(x)
    for section in sections:
        if want[0] != section["name"]:
            return -1
        else:
            return section[want[1]]

# %%
data[".text_size"]=data["section"].agg(GetSectionData, 0, (".text", "size"))
data[".rdata_size"]=data["section"].agg(GetSectionData, 0, (".rdata", "size"))
data[".data_size"]=data["section"].agg(GetSectionData, 0, (".data", "size"))
data[".rsrc_size"]=data["section"].agg(GetSectionData, 0, (".rsrc", "size"))
data[".reloc_size"]=data["section"].agg(GetSectionData, 0, (".reloc", "size"))

# %%
data[".text_vsize"]=data["section"].agg(GetSectionData, 0, (".text", "vsize"))
data[".rdata_vsize"]=data["section"].agg(GetSectionData, 0, (".rdata", "vsize"))
data[".data_vsize"]=data["section"].agg(GetSectionData, 0, (".data", "vsize"))
data[".rsrc_vsize"]=data["section"].agg(GetSectionData, 0, (".rsrc", "vsize"))
data[".reloc_vsize"]=data["section"].agg(GetSectionData, 0, (".reloc", "vsize"))

# %%
data[".text_entropy"]=data["section"].agg(GetSectionData, 0, (".text", "entropy"))
data[".rdata_entropy"]=data["section"].agg(GetSectionData, 0, (".rdata", "entropy"))
data[".data_entropy"]=data["section"].agg(GetSectionData, 0, (".data", "entropy"))
data[".rsrc_entropy"]=data["section"].agg(GetSectionData, 0, (".rsrc", "entropy"))
data[".reloc_entropy"]=data["section"].agg(GetSectionData, 0, (".reloc", "entropy"))

# %%
data.columns
# Out:
# Index(['md5', 'sha1', 'sha256', 'reported_hash', 'reported_family', 'aliases',
#        'report_source', 'appeared', 'strings', 'general', 'header', 'section',
#        'imports', 'exports', 'datadirectories', 'file_size_bytes',
#        'virtual_file_size_bytes', 'has_debug', 'num_exports', 'num_imports',
#        'has_resources', 'num_strings', 'avg_string_len',
#        'num_printable_strings', 'num_path_strings', 'num_url_strings',
#        'num_registry_strings', 'entry_point', '.text_size', '.rdata_size',
#        '.data_size', '.rsrc_size', '.reloc_size', '.text_vsize',
#        '.rdata_vsize', '.data_vsize', '.rsrc_vsize', '.reloc_vsize',
#        '.text_entropy', '.rdata_entropy', '.data_entropy', '.rsrc_entropy',
#        '.reloc_entropy'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   md5                      3095 non-null   object
#  1   sha1                     3095 non-null   object
#  2   sha256                   3095 non-null   object
#  3   reported_hash            3095 non-null   object
#  4   reported_family          3095 non-null   object
#  5   aliases                  3095 non-null   object
#  6   report_source            3095 non-null   object
#  7   appeared                 3095 non-null   object
#  8   strings                  3095 non-null   object
#  9   general                  3095 non-null   object
#  10  header                   3095 non-null   object
#  11  section                  3095 non-null   object
#  12  imports                  3095 non-null   object
#  13  exports                  3095 non-null   object
#  14  datadirectories          3095 non-null   object
#  15  file_size_bytes          3095 non-null   int64
#  16  virtual_file_size_bytes  3095 non-null   int64
#  17  has_debug                3095 non-null   int64
#  18  num_exports              3095 non-null   int64
#  19  num_imports              3095 non-null   int64
#  20  has_resources            3095 non-null   int64
#  21  num_strings              3095 non-null   int64
#  22  avg_string_len           3095 non-null   float64
#  23  num_printable_strings    3095 non-null   int64
#  24  num_path_strings         3095 non-null   int64
#  25  num_url_strings          3095 non-null   int64
#  26  num_registry_strings     3095 non-null   int64
#  27  entry_point              3095 non-null   object
#  28  .text_size               3095 non-null   int64
#  29  .rdata_size              3095 non-null   int64
#  30  .data_size               3095 non-null   int64
#  31  .rsrc_size               3095 non-null   int64
#  32  .reloc_size              3095 non-null   int64
#  33  .text_vsize              3095 non-null   int64
#  34  .rdata_vsize             3095 non-null   int64
#  35  .data_vsize              3095 non-null   int64
#  36  .rsrc_vsize              3095 non-null   int64
#  37  .reloc_vsize             3095 non-null   int64
#  38  .text_entropy            3095 non-null   float64
#  39  .rdata_entropy           3095 non-null   float64
#  40  .data_entropy            3095 non-null   float64
#  41  .rsrc_entropy            3095 non-null   int64
#  42  .reloc_entropy           3095 non-null   int64
# dtypes: float64(4), int64(23), object(16)
# memory usage: 1.0+ MB

# %%
data.drop(["section", "general", "strings"], axis=1, inplace=True)

# %%
data["appeared"]
# Out:
# 0       2018-12
# 1       2016-10
# 2       2017-05
# 3       2017-07
# 4       2018-10
#          ...
# 3090    2016-08
# 3091    2017-04
# 3092    2019-03
# 3093    2021-01
# 3094    2018-01
# Name: appeared, Length: 3095, dtype: object

# %%
data["appeared_2"] = pd.to_datetime(data["appeared"])

# %%
# data["appeared"]

# %%
# data.info()

# %%
data.to_csv("motif_cleaned.csv")

# %% [markdown]
# # Import Data

# %%
import_data = data[["imports", "appeared_2"]].copy()

# %%
import_data.head(5)
# Out:
#                                              imports appeared_2
# 0  {'NETAPI32.dll': ['NetScheduleJobAdd', 'NetUse... 2018-12-01
# 1  {'oleaut32.dll': ['SysFreeString', 'SysReAlloc... 2016-10-01
# 2  {'KERNEL32.dll': ['Sleep', 'GetLastError', 'Mu... 2017-05-01
# 3  {'VERSION.dll': ['GetFileVersionInfoW', 'VerQu... 2017-07-01
# 4  {'KERNEL32.dll': ['GetOEMCP', 'SetErrorMode', ... 2018-10-01

# %%
data_formatted = {}
